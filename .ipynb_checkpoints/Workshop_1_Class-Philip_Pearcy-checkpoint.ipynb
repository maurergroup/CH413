# %%
from IPython.display import HTML
from IPython.display import display

# Taken from https://stackoverflow.com/questions/31517194/how-to-hide-one-specific-cell-input-or-output-in-ipython-notebook
tag = HTML('''<script>
code_show=true; 
function code_toggle() {
    if (code_show){
        $('div.cell.code_cell.rendered.selected div.input').hide();
    } else {
        $('div.cell.code_cell.rendered.selected div.input').show();
    }
    code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
Some hidden code... to show/hide this cell's raw code input, click (or double click if stubborn!) <a href="javascript:code_toggle()">here</a>.''')
display(tag)

############### Write code below ##################
from IPython.core.display import HTML
def css_styling():
    styles = open("./ES_ML_SOSSO/colors.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#     if (code_show){
#         $('div.cell.code_cell.rendered.selected div.input').hide();
#     } else {
#         $('div.cell.code_cell.rendered.selected div.input').show();
#     }
#     code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# Some hidden code... to show/hide this cell's raw code input, click (or double click if stubborn!) <a href="javascript:code_toggle()">here</a>.
# <style>
# div.warn {
#     background-color: #b3b3ff;
#     border-color: #0000b3;
#     border-left: 5px solid #0000b3;
#     padding: 0.5em;
#     }
#  </style>

# %% [markdown]
# # CH413: Computational Workshop 1
# ## Machine Learning for Drug Discovery
#
# In this workshop, we are going to use a Gaussian process to build a machine learning model for the solubility of a molecular dataset. To this end, we will use some computational tools, most notably...

# %% [markdown]
# ### Jupyter notebooks
#
# <img src="./ES_ML_SOSSO/jn_logo.png" width="300">
#
# **This!** is actually a Jupyter notebook! It allows you to:
#
# - Write down some text
# - Write computer programs using a number of languages: we are going to use Python
# - Visualize the outcome of your calculations
# - Take advantage of powerful computational tools
#
# All of this in one place! First things first...

# %% [markdown]
# <div class=warn>
# These blue boxes contain instructions for you to follow, or stuff for you to do
# <h2>How to access this Jupyter notebook</h2>
#
# * <b>Step 1</b>: Open a web browser and go to [this page](https://mnf145.csc.warwick.ac.uk:8987/module/CH413). <br>
# * <b>Step 2</b>: The Notebook Launcher pops up: select the CH413 module and fill in the boxes using your SCRTP username and password <br>
# * <b>Step 3</b>: Open the Jupyter notebook you are interested in, e.g. Workshop_1_Class.ipynb <br>
# * <b>Step 4</b>: Make a copy of the orginal notebook (which is read only). In the toolbar on top of the notebook: File - Make a Copy <br>
# * <b>Step 5</b>: You're all set! <br><br>
# <b> Remember: </b> You can access this notebook at home at any time by going through the same steps on e.g. your laptop - all the changes you have made will be saved and synced! <br>
# <div/>

# %% [markdown]
# ## Right... but what - is - a Jupyter notebook exactly?
# A Jupyter notebook is a collection of "cells" - blocks within which we can e.g. write down an equation or plot a function. We will use "Markdown cells" to write down text and equations, and "Code cells" to do everything else. Cells can be inserted (and copied, and pasted, and cut!) via the toolbar above. Once we are happy with the content of a given cell, we have to "Run" it - to execute it, by holding the shift key and hitting the enter/return key. The Jupyter notebook will take care of running the cell, and let us know if everything is ok. You can also run a cell, or indeed all the cells in a notebook, via the same toolbar above. Let's have a look at Markdown and Code cells, then...

# %% [markdown]
# ### This is a Markdown cell
# Thus, we can write into it! To edit the cell, a double click of the mouse should do.
# We can play around with **bold text**, *italic text*,
# # Big Headings,
# ## Small Headings,
# ### Tiny Headings,
# and much more. Importantly, we can also write down equations using LaTeX syntax. This one should hopefully look quite familiar:
#
# $$
# K(\bf{x}_i,\bf{x}_j)=\exp\left ( -\frac{||\bf{x}_i - \bf{x}_j||^2}{L}\right )
# $$
#
# Remember, LaTeX may look daunting at the beginning, but it is the best documented markup language in the world, and after a little while it becomes natural. In fact, journal articles and books are ultimately *all* typesetted in LaTeX!

# %% [markdown]
# <div class=warn>
# Write down the expression of an exponential kernel - in a new Markdown cell. Don't know where to start? Google it!
# <div/>

# %% [markdown]
# New Kernel
# $$
# K(\bf{x}_i,\bf{x}_j)=\sigma^2\exp\left ( -\frac{2\sin^2(\pi|\bf{x}_i - \bf{x}_j|)/p}{L^2}\right )
# $$

# %%
string = "This is a Code cell"
print(string)
# Out:
# This is a Code cell

# %% [markdown]
# ### Wait, what happened?
# In the cell above, we actually used some Python already! We did two things:
#
# - 1. We have stored some text (**This is a code cell**) into a *variable* we have called **string**
# - 2. We have printed the variable **string**

# %% [markdown]
# ## P is for Python!
# What's Python anyway? It's a programming language - one of many, such as C++ or Fortran. It is especially popular these days, mostly because there exist a phenomenal amount of Python libraries (or packages, or modules...) out there that can be harnessed for free. These can in turn be used to do all sort of interesting things, from machine learning for drug design to stock market analysis. This is the reason why a decent knowledge of Python is now often indicated as a desirable (transferable!) skill when interviewing for jobs in Pharma companies and finance alike.
# <img src="./ES_ML_SOSSO/python_logo.png" width="300">
# Great - now that we know everything about Python, Jupyter Notebooks, Markdown and Code cells, we have what we need to make a start...

# %%
import numpy as np

# %%
# %%capture
from __future__ import division

# This is a comment - the # tells Python to just ignore whatever follows

# First things first, we are going to "take advantage of powerful computational tools"
# Specifically, we are going to "import" a number of libraries - an incredibly useful set of of Pythonic tools
# that will save us a lot of time. off we go...

import pandas as pd # Deal with dataframes
import numpy as np # numpy = numeric python. Useful when dealing with e.g. arrays...
import ES_ML_SOSSO.chemfun as cf # gabriele's masters student program
from numpy.linalg import eigvalsh,eigh

from rdkit import Chem # rdkit contains a number of molecular descriptors
from rdkit.Chem.rdmolops import GetAdjacencyMatrix
from rdkit.Chem import AllChem
from rdkit.Chem.Crippen import MolLogP,MolMR

from sklearn.gaussian_process import GaussianProcessRegressor # sklearn = scikit-learn - which we'll use for our Gaussian process
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C
from sklearn.gaussian_process.kernels import Matern, WhiteKernel

import matplotlib.pyplot as plt # useful to plot data
from sklearn.model_selection import train_test_split
#import networkx as nx
from numpy import linalg as LA
% matplotlib inline
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole #Needed to show molecules
from rdkit.Chem.Draw.MolDrawing import MolDrawing, DrawingOptions #Only needed if modifying defaults
DrawingOptions.bondLineWidth=1.8

# %%
a = 5
b = 6

# %%
a + b
# Out:
# 11

# %% [markdown]
# ##  The dataset
# The dataset we are going to use can be downloaded for free at http://moleculenet.ai/datasets-1. It contains the solubility in $\log[\text{mols/litre}]$ of (1128) common organic small molecules in water.

# %%
# We load the dataset into the notebook, specifically into the "data" variable
# using the panda library ("import pandas as pd" above).
# Specifically, we'll use the read_table function, hence...
data=pd.read_table("./ES_ML_SOSSO/dataset.dat",header=None)
# Out:
# /anaconda3/envs/ML/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   after removing the cwd from sys.path.

# %%
# Let's have a look at our dataset
data
# Out:
#                                                       0      1
# 0     OCC3OC(OCC2OC(OC(C#N)c1ccccc1)C(O)C(O)C2O)C(O)... -0.770
# 1                                Cc1occc1C(=O)Nc2ccccc2 -3.300
# 2                                  CC(C)=CCCC(C)=CC(=O) -2.060
# 3                    c1ccc2c(c1)ccc3c2ccc4c5ccccc5ccc43 -7.870
# 4                                               c1ccsc1 -1.330
# 5                                        c2ccc1scnc1c2  -1.500
# 6                    Clc1cc(Cl)c(c(Cl)c1)c2c(Cl)cccc2Cl -7.320
# 7                      CC12CCC3C(CCc4cc(O)ccc34)C2CCC1O -5.030
# 8        ClC4=C(Cl)C5(Cl)C3C1CC(C2OC12)C3C4(Cl)C5(Cl)Cl -6.290
# 9      COc5cc4OCC3Oc2c1CC(Oc1ccc2C(=O)C3c4cc5OC)C(C)=C  -4.420
# 10                                            O=C1CCCN1  1.070
# 11                                     Clc1ccc2ccccc2c1 -4.140
# 12                                               CCCC=C -2.680
# 13                           CCC1(C(=O)NCNC1=O)c2ccccc2 -2.640
# ...

# %% [markdown]
# ## The SMILES format
# Our database contains 1128 lines, one line / molecule. In each line, we have the structure of the molecule (1st column) and its solubility (2nd column). The structure is encoded in the so-called SMILES format (https://en.wikipedia.org/wiki/Simplified_molecular-input_line-entry_system), which contains a limited amount of information about the structure - chiefly the identity of the atoms and their connectivity (i.e. which bonds are helding them together). A SMILES structure is thus 2D representation of a molecule - let's have a look...

# %%
from rdkit.Chem.Draw import IPythonConsole #Needed to show molecules

# We store the SMILES for each molecules in to the "smiles" (1D) array
# "data[0].values" gets the values of first column ([0], note that in Python we start counting from 0, not 1!) 
# of the (2D) "data" array 
smiles=data[0].values

# Let's do the same with the solubility values - this time, 2nd column, so data[1].values
logS=data[1].values

# %%
print(logS)
# Out:
# [-0.77  -3.3   -2.06  ... -3.091 -3.18  -4.522]

# %%
# Draw the structure from the second [1] SMILES 
test_mol=Chem.MolFromSmiles(smiles[1])

# Visualize the structure
test_mol

# %% [markdown]
# <div class=warn>
# Add hydrogen atoms to the structure of the last molecule within the dataset and visualize the result
# <div/>

# %%
idx = len(data)-1
last_mol = Chem.MolFromSmiles(smiles[1])
add_Hs = Chem.AddHs(test_mol)
add_Hs

# %%
# Setting indices to know how data is split 
indices=np.arange(len(smiles))

# %%
# Load saved train/test sets
Train=np.load('./ES_ML_SOSSO/Train.npy',allow_pickle = True)
Test=np.load('./ES_ML_SOSSO/Test.npy',allow_pickle = True)
TrainTargets=np.load('./ES_ML_SOSSO/TrainTargets.npy',allow_pickle = True)
TestTargets=np.load('./ES_ML_SOSSO/TestTargets.npy',allow_pickle = True)

# %%
len(Test)
# Out:
# 226

# %%
len(TestTargets)
# Out:
# 226

# %%
# Convert into a different format (rdkit internal)
MFSTR=cf.SMILES2MOLES(Train)
MFSTE=cf.SMILES2MOLES(Test)

# %%
# Choosing the descriptors for training (SDTR) and test (SDTE) sets. 
from rdkit.Chem import Descriptors

# %%
# initialise an empty list
#empty_list = []
#npp.mean(empty_list)
#np.array(empty_list)

# %%
SDTR=[]
for m in MFSTR:
    desc=[]
    desc.append(Chem.Lipinski.NumAromaticRings(m)) # Number of aromatic rings
    desc.append(Chem.Lipinski.NumHAcceptors(m))    # Number of hydrogen bond acceptors
    desc.append(Chem.Lipinski.HeavyAtomCount(m))   # Number of heavy atoms within the molecule
    desc.append(Chem.Lipinski.NumSaturatedRings(m))# Number of saturated rings
    desc.append(Chem.Lipinski.NHOHCount(m)) # Number of NH and OH's in molecules
    desc.append(Descriptors.TPSA(m))               # from J. Med. Chem. 43:3714-7, (2000)
    SDTR.append(desc)

SDTE=[]
for m in MFSTE:
    desc=[]
    desc.append(Chem.Lipinski.NumAromaticRings(m)) 
    desc.append(Chem.Lipinski.NumHAcceptors(m))
    desc.append(Chem.Lipinski.HeavyAtomCount(m))
    desc.append(Chem.Lipinski.NumSaturatedRings(m))
    desc.append(Chem.Lipinski.NHOHCount(m))
    desc.append(Descriptors.TPSA(m))
    SDTE.append(desc)

# %% [markdown]
# ## Choice of new descriptors
# To understand the solubility of the molecules, the polarity is important and this varies dependning on the nature of the functional groups within the molecule. I have added NHOHCount and NumSaturatedRings as this will give information about how many polar regions (NH, OH groups) and non-polar regions (saturated rings) are present which will help inform us about the solubility.

# %% [markdown]
# <div class=warn>
#
# * Modify the list of descriptors using rdkit built-in descriptors (a list can be found [here](http://www.rdkit.org/docs/GettingStartedInPython.html#list-of-available-descriptors))<br>
# * Motivate your choice (in a Markdown cell)
#
# <div/>

# %%
# Use a Gaussian process (GP) to fit our training set

# Choosing the kernel: radial basis function, initial lengthscale =1
# Note that we are setting boundaries for the lengthscale - to avoid overfitting
# There are obviously better ways to do this...
kernel=RBF(length_scale_bounds=(5e-02,10)) # L is bound between 5e-02 and 10. RBF is shown at top of notebook.

# Define our GP
# normalize_y=True -> the mean of the observed target values is set to zero

# To try and avoid finding a local, rather than a global, maximum in the marginal likelihood
# n_restarts_optimizer > 0, which will run the optimization algorithm as many times as specified,
# using randomly-chosen starting coordinates, in the hope that a globally-competitive value can be discovered

# Add some noise to the actual data - useful to improve the numerical accuracy of the fitting

gp=GaussianProcessRegressor(kernel=kernel,normalize_y=True,n_restarts_optimizer=10,alpha=1e-4);

# Fit our GP model
gp.fit(SDTR,TrainTargets);

# %%
# Use the trained GP to predict the solubility of our training set...
TrainPred=gp.predict(SDTR).reshape(-1,1)
# ... and of our test set
TestPred=gp.predict(SDTE).reshape(-1,1)
# The reshape(-1,1) bit is needed to convert numpy arrays into scikit-learn compatible inputs...

# %%
from sklearn.metrics import mean_squared_error

# How are we doing? 
# Let us calculate the mean squared error of our prediction for the training set 
# with respect to the actual solubility values
mse_train=mean_squared_error(TrainTargets,TrainPred)
print("MSE (training)) = ", mse_train)

# Now let's do the same for the test set...
mse_test=mean_squared_error(TestTargets,TestPred)
print("MSE (test)) = ", mse_test)
# Out:
# MSE (training)) =  0.10661872119372065
# MSE (test)) =  1.2886820829873933

# %%
# Let's have a look!
fig=plt.figure(num=None,figsize=(4,4),dpi=500,facecolor='w',edgecolor='k')
plt.xlabel('Exp. Solubility [log(mols/litre)]',fontsize=8)
plt.ylabel('GP prediction [log(mols/litre)]',fontsize=8)
plt.scatter(TrainTargets,TrainPred,color='rebeccapurple',alpha=0.75,label='Training Set')
plt.scatter(TestTargets,TestPred,color='lime',alpha=0.5,label='Test Set',facecolors='none')
plt.legend(fontsize=8,loc=4);
#plt.savefig('4.png');

# %% [markdown]
# <div class=warn>
# <h2>Assessed part of the workshop</h2>
#     <i>If you don't know it... Google it!</i>
#
# * <b>Step 1 [5%]</b>: Import the "FreeSolv" dataset from [http://moleculenet.ai/datasets-1]. <br>
# * <b>Step 2 [5%]</b>: Split the dataset, by (randomly!) assigning 70% of the structure to the trainining set and 30% to the test set.<br>
# * <b>Step 3 [5%]</b>: Plot the probability density function of the target values for both the training and the test dataset. <br>
# * <b>Step 4 [10%]</b>: Choose your descriptors! <br>
# * <b>Step 5 [25%]</b>: Fit a Gaussian Process using a [rational quadratic kernel](https://scikit-learn.org/stable/modules/generated/sklearn.gaussian_process.kernels.RationalQuadratic.html#sklearn.gaussian_process.kernels.RationalQuadratic), setting the initial value of the lengthscale to 1 and the initial value of the hyperparameter $\alpha$ to 0.1 in combination with a white kernel (setting the initial value of the noise level to 1). <br>
# * <b>Step 6 [10%]</b>: Visualize the result via a scatter plot (GP prediction vs Exp. Free Energy of Solvation) including training and test sets predictions.<br>
# * <b>Step 7 [15%]</b>: Optimize the value of $\alpha$ according to the mean squared error of the predictions for the dataset.<br>
# * <b>Step 8 [5%]</b>: Visualize the (hopefully improved) result via a scatter plot (GP prediction vs Exp. Free Energy of Solvation) including training and test sets predictions.<br>
# * <b>Step 9 [10%]</b>: Calculate the mean sqaure error and the Person's correlation coefficient relative to your prediction. Error bars can be added via [cross validation](https://scikit-learn.org/stable/modules/cross_validation.html).
# <div/>

# %% [markdown]
# ## Step 1
# ### Import the "FreeSolv" dataset

# %%
import pandas as pd # import pandas to the notebook.
import os # allows you to interface with the underlying operating system that Python is running on.

# %%
pwd # see the default directory
# Out:
# '/Users/wolf/Work/CODES/GIT/CH413'

# %%
FS = pd.read_csv(r"./ES_ML_SOSSO/FreeSolv.csv") # define FreeSolv.csv file as "FS"

# %%
FS # see the dataset has uploaded.
# Out:
#                                    iupac                            smiles  \
# 0       4-methoxy-N,N-dimethyl-benzamide            CN(C)C(=O)c1ccc(cc1)OC
# 1               methanesulfonyl chloride                      CS(=O)(=O)Cl
# 2                      3-methylbut-1-ene                          CC(C)C=C
# 3                        2-ethylpyrazine                        CCc1cnccn1
# 4                            heptan-1-ol                          CCCCCCCO
# 5                     3,5-dimethylphenol                   Cc1cc(cc(c1)O)C
# 6                     2,3-dimethylbutane                        CC(C)C(C)C
# 7                    2-methylpentan-2-ol                       CCCC(C)(C)O
# 8                1,2-dimethylcyclohexane              C[C@@H]1CCCC[C@@H]1C
# 9                             butan-2-ol                       CC[C@H](C)O
# 10                        dibromomethane                           C(Br)Br
# ...

# %% [markdown]
# ## Step 2
# ### Split the dataset, by (randomly) assigning 70% of the structure to the trainining set and 30% to the test set

# %%
from sklearn.model_selection import train_test_split # import function which will split the dataset

# %%
FS_train, FS_test = train_test_split(FS,test_size=0.3) # Take FS and split into FS_train and FS_test, with 30% being in test
print("\nFS_train:\n") # Print FS_train title
print(FS_train.head()) # Print first five rows in FS_train dataset
print(FS_train.shape) # Print size of array

print("\nFS_test:\n") # Repeat for FS_test
print(FS_test.head())
print(FS_test.shape)
# Out:
# FS_train:
#
#                                      iupac                       smiles  expt  \
# 569                          hexan-1-amine                      CCCCCCN -3.95
# 344  [2-benzhydryloxyethyl]-dimethyl-amine  CN(C)CCOC(c1ccccc1)c2ccccc2 -9.34
# 263                                 decane                   CCCCCCCCCC  3.16
# 160                            cyclohexene                    C1CCC=CC1  0.14
# 620                               o-xylene                   Cc1ccccc1C -0.90
#
#       calc
# 569 -2.772
# 344 -7.873
# 263  3.335
# 160  1.175
# 620 -0.851
# (449, 4)
#
# FS_test:
#
#                           iupac                                smiles   expt  \
# 117          4-methylmorpholine                             CN1CCOCC1  -6.32
# 413                flurbiprofen  C[C@@H](c1ccc(c(c1)F)c2ccccc2)C(=O)O  -8.42
# 462              3-nitroaniline             c1cc(cc(c1)[N+](=O)[O-])N  -8.84
# ...

# %% [markdown]
# 449 and 193 are 70% and 30% of 642 respectively. Thus, the dataset has been split correctly.

# %% [markdown]
# ## Step 3
# ### Plot the probability density function of the target values for both the training and the test dataset.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
sns.set(color_codes=True)

# %%
# Density Plot and Histogram of FS_train experimental solvation energy data.
sns.distplot(FS_train['expt'], label='FS_train', hist=False, kde=True, 
             bins=int(180/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 2, 'shade':True})

# Density Plot and Histogram of FS_test experimental solvation energy data.
sns.distplot(FS_test['expt'], label='FS_test', hist=False, kde=True, 
             bins=int(180/5), color = 'orange', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 2, 'shade':True})

# Plot formatting
plt.title('Density plot of FS_train and FS_test experimental solvation energy data')
plt.xlabel('Solvation energy (kcal/mol)')
plt.ylabel('Density')
plt.legend(loc ='upper left')

plt.show()
# Out:
# /anaconda3/envs/ML/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Step 4
# ### Choose your descriptors

# %%
from rdkit import Chem # rdkit contains a number of molecular descriptors
from rdkit.Chem import AllChem
import ES_ML_SOSSO.chemfun as cf # Use to convert SMILES to Moles

# %%
from rdkit.Chem import Descriptors # Load the descriptors
from rdkit.Chem import Lipinski # Load Lipinski descriptors
from rdkit.Chem import rdMolDescriptors # Load rdMol descriptors

# %%
print(Descriptors)
# Out:
# <module 'rdkit.Chem.Descriptors' from '/anaconda3/envs/ML/lib/python3.6/site-packages/rdkit/Chem/Descriptors.py'>

# %%
FS_train_SMILES = FS_train['smiles'].to_numpy(); # Extract SMILES from FS_train data
FS_test_SMILES = FS_test['smiles'].to_numpy(); # Extract SMILES from FS_train data
FS_train_expt = FS_train['expt'].to_numpy(); # Extract expt from FS_train data and convert to numpy array
FS_test_expt = FS_test['expt'].to_numpy(); # Extract expt from FS_test data and convert to numpy array
S2MTR=cf.SMILES2MOLES(FS_train_SMILES) # Convert FS_train_SMILES numpy array in MOLES
S2MTE=cf.SMILES2MOLES(FS_test_SMILES) # # Convert FS_test_SMILES numpy array in MOLES

# %%
# Read paper to see what could affect solvation: J. Chem. Eng. Data 2017, 62, 5, 1559-1569.

Des_FS_train=[] # Form an empty list that will be used to contain all the descriptors.
for m in S2MTR:
    desc=[]
    desc.append(Descriptors.MaxAbsPartialCharge(m)) # Gives a measure of the maximum absolute partial charge of the parts of the molecule.
    #desc.append(Descriptors.MinAbsPartialCharge(m)) # Gives a measure of the minimum absolute partial charge of the parts of the molecule.
    desc.append(Chem.Lipinski.NHOHCount(m)) # -NH's and -OH's will affect solvation.
    desc.append(Chem.Lipinski.NumHeteroatoms(m)) # Heteroatoms have different electronegativies, which affect the solvation.
    desc.append(Chem.Lipinski.NumAromaticRings(m)) # Number of aromatic rings
    desc.append(Chem.Lipinski.NumSaturatedRings(m)) # Number of saturated rings
    desc.append(Chem.Lipinski.NumAliphaticRings(m)) # Number of aliphatic rings 
    desc.append(Descriptors.FpDensityMorgan2(m)) # Topological descriptor
    #desc.append(Descriptors.FpDensityMorgan3(m)) # Topological descriptor
    desc.append(Chem.Lipinski.NumHDonors(m)) # Number of hydrogen donors
    desc.append(Chem.Lipinski.NumHAcceptors(m)) # Number of hydrogen accepetors
    desc.append(Descriptors.TPSA(m))
    Des_FS_train.append(desc)

# Copy descriptors for test
Des_FS_test=[]
for m in S2MTE:
    desc=[]
    desc.append(Descriptors.MaxAbsPartialCharge(m)) # Gives a measure of the maximum absolute partial charge of the parts of the molecule.
    #desc.append(Descriptors.MinAbsPartialCharge(m)) # Gives a measure of the minimum absolute partial charge of the parts of the molecule.
    desc.append(Chem.Lipinski.NHOHCount(m)) # -NH's and -OH's will affect solvation.
    desc.append(Chem.Lipinski.NumHeteroatoms(m)) # Heteroatoms have different electronegativies, which affect the solvation.
    desc.append(Chem.Lipinski.NumAromaticRings(m)) # Number of aromatic rings
    desc.append(Chem.Lipinski.NumSaturatedRings(m)) # Number of saturated rings
    desc.append(Chem.Lipinski.NumAliphaticRings(m)) # Number of aliphatic rings
    desc.append(Descriptors.FpDensityMorgan2(m)) # Topological descriptor
    #desc.append(Descriptors.FpDensityMorgan3(m)) # Topological descriptor
    desc.append(Chem.Lipinski.NumHDonors(m)) # Number of hydrogen donors
    desc.append(Chem.Lipinski.NumHAcceptors(m)) # Number of hydrogen acceptors
    desc.append(Descriptors.TPSA(m))
    Des_FS_test.append(desc)

# %% [markdown]
# ## Step 5
# ### Fit a Gaussian Process using a rational quadratic kernel, setting the initial value of the lengthscale to 1 and the initial value of the hyperparameter  𝛼  to 0.1 in combination with a white kernel (setting the initial value of the noise level to 1).

# %%
from sklearn.gaussian_process import GaussianProcessRegressor # sklearn = scikit-learn - which we'll use for our Gaussian process
from sklearn.gaussian_process.kernels import RationalQuadratic as RQ
from sklearn.gaussian_process.kernels import Matern, WhiteKernel as WK

# %%
kernel = RQ(length_scale=1.0,alpha=0.1,length_scale_bounds=(1e-05, 100000.0), alpha_bounds=(1e-05, 100000.0)) \
    + WK(noise_level=1.0, noise_level_bounds=(1e-05, 100000.0))
# Kernel used for Gaussian process (RQ) and also contains noise (WK). Alpha in RQ = 0.1, noise level in WK = 1.0

# %%
gp = GaussianProcessRegressor(kernel=kernel,normalize_y=True,n_restarts_optimizer=10,alpha=1e-4)

# %%
gp.fit(Des_FS_train, FS_train_expt); 
#Fit a Gaussian Process using a rational quadratic kernel, using the FS training descriptor list and the FS training set experimental data.

# %%
FS_train_pred=gp.predict(Des_FS_train).reshape(-1,1)
# ... and of our test set
FS_test_pred=gp.predict(Des_FS_test).reshape(-1,1)

# %%
from sklearn.metrics import mean_squared_error
# Calculate the mean squared error of our prediction for the training set with respect to the actual solvation values
mse_train=mean_squared_error(FS_train_expt,FS_train_pred)
print("MSE (training) = ", mse_train)

# Do the same for the test set
mse_test=mean_squared_error(FS_test_expt,FS_test_pred)
print("MSE (test) = ", mse_test)
# Out:
# MSE (training) =  2.4118542344989975
# MSE (test) =  5.324770602885107

# %% [markdown]
# ## Step 6
# ### Visualize the result via a scatter plot (GP prediction vs Exp. Free Energy of Solvation) including training and test sets predictions.

# %%
# Plot the data
fig=plt.figure(num=None,figsize=(4,4),dpi=500,facecolor='w',edgecolor='k')
plt.xlabel('Exp. Solvation energy (kcal/mol)',fontsize=8)
plt.ylabel('GP prediction (kcal/mol)',fontsize=8)
plt.scatter(FS_train_expt,FS_train_pred,color='blue',alpha=0.75,label='Training Set')
plt.scatter(FS_test_expt,FS_test_pred,color='orange',alpha=0.5,label='Test Set',facecolors='none')
plt.legend(fontsize=8,loc='upper left');
#plt.savefig('4.png');

# %% [markdown]
# ## Step 7
# ### Optimize the value of  𝛼  according to the mean squared error of the predictions for the dataset.

# %%
kernel_2 = RQ(length_scale=0.05,alpha=0.1,length_scale_bounds=(1e-05, 100000.0), alpha_bounds=(1e-05, 100000.0)) \
    + WK(noise_level=100, noise_level_bounds=(1e-05, 100000.0))
# kernel used for Gaussian process (RQ) and also contains noise (WK). Alpha in RQ = 1e-05, noise level in WK = 1.0 
gp_2 = GaussianProcessRegressor(kernel=kernel_2,normalize_y=True,n_restarts_optimizer=10,alpha=0.01)
gp_2.fit(Des_FS_train, FS_train_expt); 
FS_train_pred_2=gp_2.predict(Des_FS_train).reshape(-1,1)
# ... and of our test set
FS_test_pred_2=gp_2.predict(Des_FS_test).reshape(-1,1)
mse_train_2=mean_squared_error(FS_train_expt,FS_train_pred_2)
mse_test_2=mean_squared_error(FS_test_expt,FS_test_pred_2)
print("MSE (training) = ", mse_train)
print("MSE (test) = ", mse_test)
print("MSE (training) = ", mse_train_2)
print("MSE (test) = ", mse_test_2)
# Out:
# MSE (training) =  2.4118542344989975
# MSE (test) =  5.324770602885107
# MSE (training) =  2.411854391714336
# MSE (test) =  5.324770765594909

# %%
FS_train_pred
# Out:
# array([[-4.72558831e+00],
#        [-4.95593290e+00],
#        [ 1.17014592e+00],
#        [ 7.61284755e-01],
#        [-3.72158455e-01],
#        [-4.62872186e+00],
#        [-2.49427683e+00],
#        [-4.62092194e+00],
#        [-8.17173618e+00],
#        [-4.81953453e+00],
#        [-1.14762620e+00],
#        [-3.27061976e-02],
#        [-3.39958415e-03],
#        [-2.00879484e+00],
#        [-6.10392603e+00],
#        [-8.33744874e+00],
#        [-7.47005795e+00],
#        [ 6.08376682e-01],
#        [-6.45639407e+00],
#        [-4.76751768e+00],
#        [-6.19107296e+00],
#        [-5.75989782e+00],
#        [-3.67563509e+00],
#        [-4.09867119e+00],
#        [-4.91287348e+00],
#        [-4.10708333e+00],
#        [-4.34792527e+00],
#        [-1.54075234e+00],
#        [-3.60151997e+00],
#        [-4.37733769e+00],
#        [-7.14600324e-01],
#        [-6.06838790e+00],
#        [-3.07060549e+00],
#        [-6.45810846e+00],
#        [ 1.37399572e+00],
# ...

# %%
FS_train_pred_2
# Out:
# array([[-4.72558833e+00],
#        [-4.95593283e+00],
#        [ 1.17014586e+00],
#        [ 7.61284669e-01],
#        [-3.72158478e-01],
#        [-4.62872183e+00],
#        [-2.49427688e+00],
#        [-4.62092191e+00],
#        [-8.17173607e+00],
#        [-4.81953453e+00],
#        [-1.14762622e+00],
#        [-3.27062143e-02],
#        [-3.39960233e-03],
#        [-2.00879482e+00],
#        [-6.10392603e+00],
#        [-8.33744862e+00],
#        [-7.47005785e+00],
#        [ 6.08376628e-01],
#        [-6.45639404e+00],
#        [-4.76751768e+00],
#        [-6.19107291e+00],
#        [-5.75989777e+00],
#        [-3.67563504e+00],
#        [-4.09867118e+00],
#        [-4.91287349e+00],
#        [-4.10708333e+00],
#        [-4.34792527e+00],
#        [-1.54075231e+00],
#        [-3.60151999e+00],
#        [-4.37733770e+00],
#        [-7.14600419e-01],
#        [-6.06838789e+00],
#        [-3.07060542e+00],
#        [-6.45810842e+00],
#        [ 1.37399570e+00],
# ...

# %% [markdown]
# ## Step 8
# ### Visualize the (hopefully improved) result via a scatter plot (GP prediction vs Exp. Free Energy of Solvation) including training and test sets predictions.

# %% [markdown]
# ## Step 9
# ### Calculate the mean sqaure error and the Person's correlation coefficient relative to your prediction. Error bars can be added via cross validation.
